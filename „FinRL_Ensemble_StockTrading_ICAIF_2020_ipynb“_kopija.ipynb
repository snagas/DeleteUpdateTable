# %% [markdown]
# <a href="https://colab.research.google.com/github/snagas/DeleteUpdateTable/blob/master/%E2%80%9EFinRL_Ensemble_StockTrading_ICAIF_2020_ipynb%E2%80%9C_kopija.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# ## install finrl library
# !pip install wrds
# !pip install swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wrds in /usr/local/lib/python3.8/dist-packages (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from wrds) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from wrds) (1.10.1)
# Requirement already satisfied: sqlalchemy<2 in /usr/local/lib/python3.8/dist-packages (from wrds) (1.4.46)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from wrds) (1.3.5)
# Requirement already satisfied: psycopg2-binary in /usr/local/lib/python3.8/dist-packages (from wrds) (2.9.5)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.8/dist-packages (from sqlalchemy<2->wrds) (2.0.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->wrds) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->wrds) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->wrds) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: swig in /usr/local/lib/python3.8/dist-packages (4.1.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/AI4Finance-Foundation/FinRL.git
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to /tmp/pip-req-build-u3g2zng2
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL.git /tmp/pip-req-build-u3g2zng2
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit 6f773cc018dfc3681f58bb30457fa94733a4caf2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2
#   Cloning https://github.com/quantopian/pyfolio.git to /tmp/pip-install-6eyxcyfv/pyfolio_2004aec80d594c96810cc460d5f85409
#   Running command git clone --filter=blob:none --quiet https://github.com/quantopian/pyfolio.git /tmp/pip-install-6eyxcyfv/pyfolio_2004aec80d594c96810cc460d5f85409
#   Resolved https://github.com/quantopian/pyfolio.git to commit 4b901f6d73aa02ceb6d04b7d83502e5c6f2e81aa
#   Preparing metadata (setup.py) ... done
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to /tmp/pip-install-6eyxcyfv/elegantrl_ec788092a6bb41b8bf70874753d7044f
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git /tmp/pip-install-6eyxcyfv/elegantrl_ec788092a6bb41b8bf70874753d7044f
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 68bf0ea4ef3fb461026ece8897deabb92aeead32
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: stockstats>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from finrl==0.3.5) (0.5.2)
# Requirement already satisfied: scikit-learn>=0.21.0 in /usr/local/lib/python3.8/dist-packages (from finrl==0.3.5) (1.2.1)
# Requirement already satisfied: importlib-metadata==4.13.0 in /usr/local/lib/python3.8/dist-packages (from finrl==0.3.5) (4.13.0)
# Requirement already satisfied: alpaca_trade_api>=2.1.0 in /usr/local/lib/python3.8/dist-packages (from finrl==0.3.5) (3.0.0)
# Requirement already satisfied: jqdatasdk in /usr/local/lib/python3.8/dist-packages (from finrl==0.3.5) (1.8.11)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from finrl==0.3.5) (1.22.4)
# Requirement already satisfied: lz4 in /usr/local/lib/python3.8/dist-packages (from finrl==0.3.5) (4.3.2)
# Requirement already satisfied: yfinance in /usr/local/lib/python3.8/dist-packages (from finrl==0.3.5) (0.2.12)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.8/dist-packages (from finrl==0.3.5) (1.3.5)
# Requirement already satisfied: exchange_calendars==3.6.3 in /usr/local/lib/python3.8/dist-packages (from finrl==0.3.5) (3.6.3)
# Requirement already satisfied: ccxt>=1.66.32 in /usr/local/lib/python3.8/dist-packages (from finrl==0.3.5) (2.8.97)
# Requirement already satisfied: gym>=0.17 in /usr/local/lib/python3.8/dist-packages (from finrl==0.3.5) (0.21.0)
# Requirement already satisfied: gputil in /usr/local/lib/python3.8/dist-packages (from finrl==0.3.5) (1.4.0)
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.8/dist-packages (from finrl==0.3.5) (2.6)
# Requirement already satisfied: stable-baselines3<2.0.0,>=1.6.2 in /usr/local/lib/python3.8/dist-packages (from finrl==0.3.5) (1.7.0)
# Requirement already satisfied: ray[default,tune]>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from finrl==0.3.5) (2.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from finrl==0.3.5) (3.5.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from exchange_calendars==3.6.3->finrl==0.3.5) (2022.7.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.8/dist-packages (from exchange_calendars==3.6.3->finrl==0.3.5) (2.8.2)
# Requirement already satisfied: korean-lunar-calendar in /usr/local/lib/python3.8/dist-packages (from exchange_calendars==3.6.3->finrl==0.3.5) (0.3.1)
# Requirement already satisfied: pyluach in /usr/local/lib/python3.8/dist-packages (from exchange_calendars==3.6.3->finrl==0.3.5) (2.2.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.8/dist-packages (from exchange_calendars==3.6.3->finrl==0.3.5) (0.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata==4.13.0->finrl==0.3.5) (3.15.0)
# Requirement already satisfied: websockets<11,>=9.0 in /usr/local/lib/python3.8/dist-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (10.4)
# Requirement already satisfied: msgpack==1.0.3 in /usr/local/lib/python3.8/dist-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (1.0.3)
# Requirement already satisfied: aiohttp==3.8.1 in /usr/local/lib/python3.8/dist-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (3.8.1)
# Requirement already satisfied: PyYAML==6.0 in /usr/local/lib/python3.8/dist-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (6.0)
# Requirement already satisfied: deprecation==2.1.0 in /usr/local/lib/python3.8/dist-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (2.1.0)
# Requirement already satisfied: requests<3,>2 in /usr/local/lib/python3.8/dist-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (2.28.2)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /usr/local/lib/python3.8/dist-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (1.5.1)
# Requirement already satisfied: urllib3<2,>1.24 in /usr/local/lib/python3.8/dist-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (1.26.14)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp==3.8.1->alpaca_trade_api>=2.1.0->finrl==0.3.5) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp==3.8.1->alpaca_trade_api>=2.1.0->finrl==0.3.5) (1.8.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp==3.8.1->alpaca_trade_api>=2.1.0->finrl==0.3.5) (22.2.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp==3.8.1->alpaca_trade_api>=2.1.0->finrl==0.3.5) (2.1.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp==3.8.1->alpaca_trade_api>=2.1.0->finrl==0.3.5) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp==3.8.1->alpaca_trade_api>=2.1.0->finrl==0.3.5) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp==3.8.1->alpaca_trade_api>=2.1.0->finrl==0.3.5) (6.0.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from deprecation==2.1.0->alpaca_trade_api>=2.1.0->finrl==0.3.5) (23.0)
# Requirement already satisfied: setuptools>=60.9.0 in /usr/local/lib/python3.8/dist-packages (from ccxt>=1.66.32->finrl==0.3.5) (64.0.2)
# Requirement already satisfied: aiodns>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from ccxt>=1.66.32->finrl==0.3.5) (3.0.0)
# Requirement already satisfied: certifi>=2018.1.18 in /usr/local/lib/python3.8/dist-packages (from ccxt>=1.66.32->finrl==0.3.5) (2022.12.7)
# Requirement already satisfied: cryptography>=2.6.1 in /usr/local/lib/python3.8/dist-packages (from ccxt>=1.66.32->finrl==0.3.5) (39.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from gym>=0.17->finrl==0.3.5) (2.2.1)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.8/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (3.19.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (3.9.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.8/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (8.1.3)
# Requirement already satisfied: virtualenv>=20.0.24 in /usr/local/lib/python3.8/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (20.20.0)
# Requirement already satisfied: grpcio>=1.32.0 in /usr/local/lib/python3.8/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (1.51.3)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.8/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (4.3.3)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.8/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (0.8.10)
# Requirement already satisfied: aiohttp-cors in /usr/local/lib/python3.8/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (0.7.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.8/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (1.10.5)
# Requirement already satisfied: py-spy>=0.2.0 in /usr/local/lib/python3.8/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (0.3.14)
# Requirement already satisfied: opencensus in /usr/local/lib/python3.8/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (0.11.1)
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.8/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (0.16.0)
# Requirement already satisfied: gpustat>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (1.0.0)
# Requirement already satisfied: colorful in /usr/local/lib/python3.8/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (0.5.5)
# Requirement already satisfied: smart-open in /usr/local/lib/python3.8/dist-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (6.3.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.21.0->finrl==0.3.5) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.21.0->finrl==0.3.5) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.21.0->finrl==0.3.5) (1.10.1)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.8/dist-packages (from stable-baselines3<2.0.0,>=1.6.2->finrl==0.3.5) (1.13.1+cu116)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from jqdatasdk->finrl==0.3.5) (1.15.0)
# Requirement already satisfied: thriftpy2>=0.3.9 in /usr/local/lib/python3.8/dist-packages (from jqdatasdk->finrl==0.3.5) (0.4.16)
# Requirement already satisfied: SQLAlchemy>=1.2.8 in /usr/local/lib/python3.8/dist-packages (from jqdatasdk->finrl==0.3.5) (1.4.46)
# Requirement already satisfied: pymysql>=0.7.6 in /usr/local/lib/python3.8/dist-packages (from jqdatasdk->finrl==0.3.5) (1.0.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->finrl==0.3.5) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->finrl==0.3.5) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->finrl==0.3.5) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->finrl==0.3.5) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->finrl==0.3.5) (4.38.0)
# Requirement already satisfied: ipython>=3.2.3 in /usr/local/lib/python3.8/dist-packages (from pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (7.9.0)
# Requirement already satisfied: seaborn>=0.7.1 in /usr/local/lib/python3.8/dist-packages (from pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.11.2)
# Requirement already satisfied: empyrical>=0.5.0 in /usr/local/lib/python3.8/dist-packages (from pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.5.5)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.8/dist-packages (from yfinance->finrl==0.3.5) (1.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.8/dist-packages (from yfinance->finrl==0.3.5) (4.11.2)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.8/dist-packages (from yfinance->finrl==0.3.5) (0.0.11)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.8/dist-packages (from yfinance->finrl==0.3.5) (1.4.4)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.8/dist-packages (from yfinance->finrl==0.3.5) (2.3.5)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.8/dist-packages (from yfinance->finrl==0.3.5) (4.9.2)
# Requirement already satisfied: pycares>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from aiodns>=1.1.1->ccxt>=1.66.32->finrl==0.3.5) (4.3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.8/dist-packages (from beautifulsoup4>=4.11.1->yfinance->finrl==0.3.5) (2.4)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.8/dist-packages (from cryptography>=2.6.1->ccxt>=1.66.32->finrl==0.3.5) (1.15.1)
# Requirement already satisfied: pandas-datareader>=0.2 in /usr/local/lib/python3.8/dist-packages (from empyrical>=0.5.0->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.9.0)
# Requirement already satisfied: nvidia-ml-py<=11.495.46,>=11.450.129 in /usr/local/lib/python3.8/dist-packages (from gpustat>=1.0.0->ray[default,tune]>=2.0.0->finrl==0.3.5) (11.495.46)
# Requirement already satisfied: psutil>=5.6.0 in /usr/local/lib/python3.8/dist-packages (from gpustat>=1.0.0->ray[default,tune]>=2.0.0->finrl==0.3.5) (5.9.4)
# Requirement already satisfied: blessed>=1.17.1 in /usr/local/lib/python3.8/dist-packages (from gpustat>=1.0.0->ray[default,tune]>=2.0.0->finrl==0.3.5) (1.20.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/dist-packages (from html5lib>=1.1->yfinance->finrl==0.3.5) (0.5.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.7.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (2.6.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (4.8.0)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.8/dist-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.18.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (4.4.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.2.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (5.7.1)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (2.0.10)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>2->alpaca_trade_api>=2.1.0->finrl==0.3.5) (2.10)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.8/dist-packages (from SQLAlchemy>=1.2.8->jqdatasdk->finrl==0.3.5) (2.0.2)
# Requirement already satisfied: ply<4.0,>=3.4 in /usr/local/lib/python3.8/dist-packages (from thriftpy2>=0.3.9->jqdatasdk->finrl==0.3.5) (3.11)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.11->stable-baselines3<2.0.0,>=1.6.2->finrl==0.3.5) (4.5.0)
# Requirement already satisfied: distlib<1,>=0.3.6 in /usr/local/lib/python3.8/dist-packages (from virtualenv>=20.0.24->ray[default,tune]>=2.0.0->finrl==0.3.5) (0.3.6)
# Requirement already satisfied: platformdirs<4,>=2.4 in /usr/local/lib/python3.8/dist-packages (from virtualenv>=20.0.24->ray[default,tune]>=2.0.0->finrl==0.3.5) (3.0.0)
# Requirement already satisfied: pyglet>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from gym>=0.17->finrl==0.3.5) (2.0.5)
# Requirement already satisfied: box2d-py==2.3.5 in /usr/local/lib/python3.8/dist-packages (from gym>=0.17->finrl==0.3.5) (2.3.5)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema->ray[default,tune]>=2.0.0->finrl==0.3.5) (0.19.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema->ray[default,tune]>=2.0.0->finrl==0.3.5) (5.12.0)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (2.11.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in /usr/local/lib/python3.8/dist-packages (from opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (0.1.3)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.8/dist-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[default,tune]>=2.0.0->finrl==0.3.5) (0.2.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt>=1.66.32->finrl==0.3.5) (2.21)
# Requirement already satisfied: google-auth<3.0dev,>=2.14.1 in /usr/local/lib/python3.8/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (2.16.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.8/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (1.58.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.7.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (4.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (0.4.8)

# %%
pip install setuptools==64.0.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting setuptools==64.0.2
#   Downloading setuptools-64.0.2-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 34.1 MB/s eta 0:00:00
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.4.0
#     Uninstalling setuptools-67.4.0:
#       Successfully uninstalled setuptools-67.4.0
# Successfully installed setuptools-64.0.2

# %%
pip show setuptools
# Out:
# Name: setuptools
# Version: 64.0.2
# Summary: Easily download, build, install, upgrade, and uninstall Python packages
# Home-page: https://github.com/pypa/setuptools
# Author: Python Packaging Authority
# Author-email: distutils-sig@python.org
# License:
# Location: /usr/local/lib/python3.8/dist-packages
# Requires:
# Required-by: aesara, arviz, ccxt, cufflinks, cvxpy, datascience, distributed, httpstan, ipython, mlxtend, numba, pandas-gbq, panel, pip-tools, pydata-google-auth, pytest, spacy, Sphinx, tensorboard, tensorflow, thinc

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
print(DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
TRAIN_START_DATE = '2009-04-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = '2022-06-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (96942, 8)

# %%
df.head()
# Out:
#          date       open       high        low      close     volume   tic  \
# 0  2009-04-01   3.717500   3.892857   3.710357   3.303860  589372000  AAPL
# 1  2009-04-01  48.779999  48.930000  47.099998  35.911705   10850100  AMGN
# 2  2009-04-01  13.340000  14.640000  13.080000  11.732111   27701800   AXP
# 3  2009-04-01  34.520000  35.599998  34.209999  26.850754    9288800    BA
# 4  2009-04-01  27.500000  29.520000  27.440001  19.726320   15308300   CAT
#
#    day
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2

# %%
df.tail()
# Out:
#              date        open        high         low       close    volume  \
# 96937  2022-05-31  503.619995  504.109985  495.660004  491.949799   4003100
# 96938  2022-05-31  210.380005  214.350006  209.110001  210.909439   9586400
# 96939  2022-05-31   51.259998   51.560001   50.849998   49.042248  25016600
# 96940  2022-05-31   43.480000   44.270000   43.049999   42.252159   8192000
# 96941  2022-05-31  127.459999  129.899994  127.419998  127.591225  12304100
#
#        tic  day
# 96937  UNH    1
# 96938    V    1
# 96939   VZ    1
# 96940  WBA    1
# 96941  WMT    1

# %%
df.shape
# Out:
# (96942, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close     volume   tic  \
# 0  2009-04-01   3.717500   3.892857   3.710357   3.303860  589372000  AAPL
# 1  2009-04-01  48.779999  48.930000  47.099998  35.911705   10850100  AMGN
# 2  2009-04-01  13.340000  14.640000  13.080000  11.732111   27701800   AXP
# 3  2009-04-01  34.520000  35.599998  34.209999  26.850754    9288800    BA
# 4  2009-04-01  27.500000  29.520000  27.440001  19.726320   15308300   CAT
#
#    day
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2

# %%
len(df.tic.unique())
# Out:
# 30

# %%
df.tic.value_counts()
# Out:
# AAPL    3315
# AMGN    3315
# WMT     3315
# WBA     3315
# VZ      3315
# V       3315
# UNH     3315
# TRV     3315
# PG      3315
# NKE     3315
# MSFT    3315
# MRK     3315
# MMM     3315
# MCD     3315
# KO      3315
# JPM     3315
# JNJ     3315
# INTC    3315
# IBM     3315
# HON     3315
# HD      3315
# GS      3315
# DIS     3315
# CVX     3315
# CSCO    3315
# CRM     3315
# CAT     3315
# BA      3315
# AXP     3315
# DOW      807
# Name: tic, dtype: int64

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
#  INDICATORS = ['macd',
#                'rsi_30',
#                'cci_30',
#                'dx_30']

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.sample(5)
# Out:
#              date        open        high         low       close    volume  \
# 45170  2015-06-09   95.519997   95.559998   94.489998   77.836029   7770900
# 26230  2012-11-01   71.099998   71.900002   70.830002   53.598572  11226000
# 76138  2019-09-05   49.930000   51.169998   49.869999   45.030411  30014200
# 57307  2017-02-06  162.419998  164.080002  162.380005  152.032944   3110500
# 19811  2011-12-14   89.589996   89.800003   86.290001   63.889194  13564500
#
#         tic  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 45170   MCD    1 -0.254477   81.767813   77.572112  46.657625 -151.290502
# 26230   JNJ    3  0.530039   54.650091   50.390384  61.397704  109.266574
# 76138  INTC    3  0.042211   44.119404   39.811522  55.656518   99.517863
# 57307    BA    0  1.956015  156.600060  143.108263  61.740778   75.434156
# 19811   CAT    2  0.129891   73.315296   63.268016  46.722091 -170.859676
#
#            dx_30  close_30_sma  close_60_sma  turbulence
# 45170  15.019842     79.434379     79.202457   16.274194
# 26230  28.421945     52.252247     51.509755   52.523632
# 76138  30.010020     42.796650     43.009768   18.745851
# 57307  16.561490    148.535145    144.536993   12.345789
# 19811  24.323508     68.785875     64.353432   34.998833

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 10_000, 
                 'ppo' : 10_000, 
                 'ddpg' : 10_000
                 }

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  203.40230421199607
# ======Model training from:  2009-04-01 to  2021-01-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/a2c/a2c_126_1
# --------------------------------------
# | time/                 |            |
# |    fps                | 32         |
# |    iterations         | 100        |
# |    time_elapsed       | 15         |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.104      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | -76.4      |
# |    reward             | 0.18433757 |
# |    std                | 1          |
# |    value_loss         | 7.8        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 48        |
# |    iterations         | 200       |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -0.592    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -80.9     |
# |    reward             | 1.6307989 |
# |    std                | 1         |
# |    value_loss         | 5.06      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 53        |
# |    iterations         | 300       |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -223      |
# |    reward             | 3.2494946 |
# |    std                | 1         |
# |    value_loss         | 34.7      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 58         |
# |    iterations         | 400        |
# |    time_elapsed       | 34         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.111      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | 46.7       |
# |    reward             | 0.67511004 |
# |    std                | 1          |
# |    value_loss         | 7.37       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 62         |
# |    iterations         | 500        |
# |    time_elapsed       | 39         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -143       |
# |    reward             | -1.3969263 |
# |    std                | 1          |
# |    value_loss         | 16.9       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 63         |
# |    iterations         | 600        |
# |    time_elapsed       | 47         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | -20.4      |
# |    reward             | 0.30125454 |
# |    std                | 1          |
# |    value_loss         | 0.601      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 65          |
# |    iterations         | 700         |
# |    time_elapsed       | 53          |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 699         |
# |    policy_loss        | -135        |
# |    reward             | -0.59424967 |
# |    std                | 1           |
# |    value_loss         | 14.6        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 64        |
# |    iterations         | 800       |
# |    time_elapsed       | 61        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -0.0144   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | 14.2      |
# |    reward             | 0.6385863 |
# |    std                | 1         |
# |    value_loss         | 0.461     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 64        |
# |    iterations         | 900       |
# |    time_elapsed       | 69        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0.0198    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | 23        |
# |    reward             | 1.3186553 |
# |    std                | 1         |
# |    value_loss         | 0.916     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 66         |
# |    iterations         | 1000       |
# |    time_elapsed       | 74         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | -38.3      |
# |    reward             | -0.7094502 |
# |    std                | 1          |
# |    value_loss         | 1.38       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 66         |
# |    iterations         | 1100       |
# |    time_elapsed       | 82         |
# |    total_timesteps    | 5500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -0.0213    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1099       |
# |    policy_loss        | 121        |
# |    reward             | -2.8021517 |
# |    std                | 1          |
# |    value_loss         | 11         |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 68          |
# |    iterations         | 1200        |
# |    time_elapsed       | 88          |
# |    total_timesteps    | 6000        |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1199        |
# |    policy_loss        | 111         |
# |    reward             | -0.39818585 |
# |    std                | 1           |
# |    value_loss         | 9.73        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 68         |
# |    iterations         | 1300       |
# |    time_elapsed       | 95         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | -85.2      |
# |    reward             | 0.70965075 |
# |    std                | 1          |
# |    value_loss         | 6.86       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 69        |
# |    iterations         | 1400      |
# |    time_elapsed       | 101       |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -0.452    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 71.2      |
# |    reward             | -1.307973 |
# |    std                | 1         |
# |    value_loss         | 8.34      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 70       |
# |    iterations         | 1500     |
# |    time_elapsed       | 106      |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -41.3    |
# |    explained_variance | -0.112   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | -28.2    |
# |    reward             | 2.753412 |
# |    std                | 1.01     |
# |    value_loss         | 3.72     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 69         |
# |    iterations         | 1600       |
# |    time_elapsed       | 114        |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | 0.559      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | 61.8       |
# |    reward             | -1.9806765 |
# |    std                | 1.01       |
# |    value_loss         | 2.29       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 70         |
# |    iterations         | 1700       |
# |    time_elapsed       | 119        |
# |    total_timesteps    | 8500       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1699       |
# |    policy_loss        | -140       |
# |    reward             | 0.79010063 |
# |    std                | 1.01       |
# |    value_loss         | 12.4       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 70        |
# |    iterations         | 1800      |
# |    time_elapsed       | 127       |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | 45.5      |
# |    reward             | 1.0020376 |
# |    std                | 1.01      |
# |    value_loss         | 1.65      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 71        |
# |    iterations         | 1900      |
# |    time_elapsed       | 133       |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | -28.7     |
# |    reward             | 2.2605321 |
# |    std                | 1.01      |
# |    value_loss         | 5.91      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 71        |
# |    iterations         | 2000      |
# |    time_elapsed       | 139       |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | -17.4     |
# |    reward             | 1.1750729 |
# |    std                | 1.01      |
# |    value_loss         | 0.414     |
# -------------------------------------
# ======A2C Validation from:  2021-01-04 to  2021-04-06
# A2C Sharpe Ratio:  0.45044508801045313
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to tensorboard_log/ppo/ppo_126_1
# ----------------------------------
# | time/              |           |
# |    fps             | 84        |
# |    iterations      | 1         |
# |    time_elapsed    | 24        |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 1.2285082 |
# ----------------------------------
# day: 2959, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 3772159.67
# total_reward: 2772159.67
# total_cost: 372759.70
# total_trades: 82714
# Sharpe: 0.768
# =================================
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 82         |
# |    iterations           | 2          |
# |    time_elapsed         | 49         |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.01523171 |
# |    clip_fraction        | 0.2        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.2      |
# |    explained_variance   | -0.00402   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 5.54       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0308    |
# |    reward               | 0.76523876 |
# |    std                  | 1          |
# |    value_loss           | 10.3       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 83          |
# |    iterations           | 3           |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016859695 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.00478     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 21.2        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0191     |
# |    reward               | -0.25329548 |
# |    std                  | 1           |
# |    value_loss           | 41.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 82          |
# |    iterations           | 4           |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.020577561 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.003      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 40.4        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0224     |
# |    reward               | -2.0083685  |
# |    std                  | 1           |
# |    value_loss           | 61.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 82          |
# |    iterations           | 5           |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.018931009 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0188     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.64        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0263     |
# |    reward               | 0.54451966  |
# |    std                  | 1.01        |
# |    value_loss           | 15.1        |
# -----------------------------------------
# ======PPO Validation from:  2021-01-04 to  2021-04-06
# PPO Sharpe Ratio:  0.3010104512292062
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cuda device
# Logging to tensorboard_log/ddpg/ddpg_126_1
# day: 2959, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 5127597.17
# total_reward: 4127597.17
# total_cost: 1171.58
# total_trades: 40973
# Sharpe: 0.822
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 60       |
# |    time_elapsed    | 196      |
# |    total_timesteps | 11840    |
# | train/             |          |
# |    actor_loss      | 12.1     |
# |    critic_loss     | 467      |
# |    learning_rate   | 0.0005   |
# |    n_updates       | 8880     |
# |    reward          | 2.599943 |
# ---------------------------------
# ======DDPG Validation from:  2021-01-04 to  2021-04-06
# ======Best Model Retraining from:  2009-04-01 to  2021-04-06
# ======Trading from:  2021-04-06 to  2021-07-06
# ============================================
# turbulence_threshold:  203.40230421199607
# ======Model training from:  2009-04-01 to  2021-04-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/a2c/a2c_189_1
# --------------------------------------
# | time/                 |            |
# |    fps                | 68         |
# |    iterations         | 100        |
# |    time_elapsed       | 7          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | -72.6      |
# |    reward             | 0.94923395 |
# |    std                | 1          |
# |    value_loss         | 10.7       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 78        |
# |    iterations         | 200       |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | 35.7      |
# |    reward             | 2.0678356 |
# |    std                | 1         |
# |    value_loss         | 1.35      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 79       |
# |    iterations         | 300      |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -41.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -333     |
# |    reward             | 4.348957 |
# |    std                | 1        |
# |    value_loss         | 83.6     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 78         |
# |    iterations         | 400        |
# |    time_elapsed       | 25         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | 83.5       |
# |    reward             | -0.5140774 |
# |    std                | 1          |
# |    value_loss         | 10.7       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 80        |
# |    iterations         | 500       |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | 141       |
# |    reward             | 1.0524694 |
# |    std                | 1         |
# |    value_loss         | 12.3      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 78         |
# |    iterations         | 600        |
# |    time_elapsed       | 38         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | -1.23e+03  |
# |    reward             | -26.340576 |
# |    std                | 1.01       |
# |    value_loss         | 1.46e+03   |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 80        |
# |    iterations         | 700       |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | 66.7      |
# |    reward             | -3.213044 |
# |    std                | 1.01      |
# |    value_loss         | 3.35      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 81        |
# |    iterations         | 800       |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0.0575    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | -25.7     |
# |    reward             | 0.3810461 |
# |    std                | 1.01      |
# |    value_loss         | 0.962     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 80       |
# |    iterations         | 900      |
# |    time_elapsed       | 56       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -41.4    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 258      |
# |    reward             | 5.142387 |
# |    std                | 1.01     |
# |    value_loss         | 57.9     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 81        |
# |    iterations         | 1000      |
# |    time_elapsed       | 61        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -13.7     |
# |    reward             | 1.9639443 |
# |    std                | 1.01      |
# |    value_loss         | 1.82      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 79       |
# |    iterations         | 1100     |
# |    time_elapsed       | 68       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -41.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -125     |
# |    reward             | 9.916172 |
# |    std                | 1        |
# |    value_loss         | 41.6     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 80        |
# |    iterations         | 1200      |
# |    time_elapsed       | 74        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | 2.9e+03   |
# |    reward             | -35.45658 |
# |    std                | 1.01      |
# |    value_loss         | 4.54e+03  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 81        |
# |    iterations         | 1300      |
# |    time_elapsed       | 80        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0.0184    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | -21.2     |
# |    reward             | -1.909064 |
# |    std                | 1.01      |
# |    value_loss         | 1.03      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 80          |
# |    iterations         | 1400        |
# |    time_elapsed       | 87          |
# |    total_timesteps    | 7000        |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | -0.0854     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1399        |
# |    policy_loss        | -10.2       |
# |    reward             | -0.49358025 |
# |    std                | 1.01        |
# |    value_loss         | 1.66        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 81         |
# |    iterations         | 1500       |
# |    time_elapsed       | 92         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -9.68e-05  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1499       |
# |    policy_loss        | -156       |
# |    reward             | -2.0013723 |
# |    std                | 1.01       |
# |    value_loss         | 17.9       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 80        |
# |    iterations         | 1600      |
# |    time_elapsed       | 99        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -13.9     |
# |    reward             | 6.09919   |
# |    std                | 1.01      |
# |    value_loss         | 0.446     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 80        |
# |    iterations         | 1700      |
# |    time_elapsed       | 105       |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -1.22e+03 |
# |    reward             | 7.654265  |
# |    std                | 1.01      |
# |    value_loss         | 1.03e+03  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 81        |
# |    iterations         | 1800      |
# |    time_elapsed       | 110       |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | 141       |
# |    reward             | -6.468018 |
# |    std                | 1.01      |
# |    value_loss         | 18.5      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 80          |
# |    iterations         | 1900        |
# |    time_elapsed       | 117         |
# |    total_timesteps    | 9500        |
# | train/                |             |
# |    entropy_loss       | -41.4       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1899        |
# |    policy_loss        | 43.7        |
# |    reward             | -0.22115774 |
# |    std                | 1.01        |
# |    value_loss         | 1.26        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 81         |
# |    iterations         | 2000       |
# |    time_elapsed       | 123        |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -41.5      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | 1.7        |
# |    reward             | 0.23722583 |
# |    std                | 1.01       |
# |    value_loss         | 0.358      |
# --------------------------------------
# ======A2C Validation from:  2021-04-06 to  2021-07-06
# A2C Sharpe Ratio:  0.12940350832451708
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to tensorboard_log/ppo/ppo_189_1
# -----------------------------------
# | time/              |            |
# |    fps             | 75         |
# |    iterations      | 1          |
# |    time_elapsed    | 27         |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.95258796 |
# -----------------------------------
# day: 3022, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 3853225.79
# total_reward: 2853225.79
# total_cost: 386747.06
# total_trades: 84547
# Sharpe: 0.761
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 2           |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013247563 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.0054     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.59        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0264     |
# |    reward               | 0.6934685   |
# |    std                  | 1           |
# |    value_loss           | 13.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 3           |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014545055 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.00701    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 12.2        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0229     |
# |    reward               | 0.29300225  |
# |    std                  | 1           |
# |    value_loss           | 46.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 4           |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011438058 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.000762   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 50.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0195     |
# |    reward               | 0.09307318  |
# |    std                  | 1.01        |
# |    value_loss           | 75.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 5           |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.018099919 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0158     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.83        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0235     |
# |    reward               | 0.67666703  |
# |    std                  | 1.01        |
# |    value_loss           | 10.4        |
# -----------------------------------------
# ======PPO Validation from:  2021-04-06 to  2021-07-06
# PPO Sharpe Ratio:  0.108683389205444
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cuda device
# Logging to tensorboard_log/ddpg/ddpg_189_1
# day: 3022, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 7480597.44
# total_reward: 6480597.44
# total_cost: 1866.87
# total_trades: 31988
# Sharpe: 1.016
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 58        |
# |    time_elapsed    | 205       |
# |    total_timesteps | 12092     |
# | train/             |           |
# |    actor_loss      | 169       |
# |    critic_loss     | 4.22e+03  |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 9069      |
# |    reward          | 7.6277285 |
# ----------------------------------
# ======DDPG Validation from:  2021-04-06 to  2021-07-06
# ======Best Model Retraining from:  2009-04-01 to  2021-07-06
# ======Trading from:  2021-07-06 to  2021-10-04
# ============================================
# turbulence_threshold:  203.40230421199607
# ======Model training from:  2009-04-01 to  2021-07-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/a2c/a2c_252_1
# --------------------------------------
# | time/                 |            |
# |    fps                | 69         |
# |    iterations         | 100        |
# |    time_elapsed       | 7          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | -0.0205    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | -35.3      |
# |    reward             | 0.10262337 |
# |    std                | 0.995      |
# |    value_loss         | 4.83       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 79        |
# |    iterations         | 200       |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | -0.0597   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | 57.3      |
# |    reward             | 1.2728192 |
# |    std                | 0.994     |
# |    value_loss         | 2.52      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 73        |
# |    iterations         | 300       |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | -0.0523   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -230      |
# |    reward             | 2.8034325 |
# |    std                | 0.995     |
# |    value_loss         | 35.3      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 77          |
# |    iterations         | 400         |
# |    time_elapsed       | 25          |
# |    total_timesteps    | 2000        |
# | train/                |             |
# |    entropy_loss       | -41         |
# |    explained_variance | 0.0117      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 399         |
# |    policy_loss        | -60.8       |
# |    reward             | -0.09380813 |
# |    std                | 0.995       |
# |    value_loss         | 7.67        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 77         |
# |    iterations         | 500        |
# |    time_elapsed       | 32         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | 457        |
# |    reward             | -1.0951219 |
# |    std                | 0.996      |
# |    value_loss         | 198        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 76         |
# |    iterations         | 600        |
# |    time_elapsed       | 38         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | 1.35e+03   |
# |    reward             | -0.6238677 |
# |    std                | 0.997      |
# |    value_loss         | 1.09e+03   |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 74        |
# |    iterations         | 700       |
# |    time_elapsed       | 46        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | 0.531     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -115      |
# |    reward             | 2.4818444 |
# |    std                | 0.995     |
# |    value_loss         | 8.08      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 73          |
# |    iterations         | 800         |
# |    time_elapsed       | 54          |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -41.1       |
# |    explained_variance | -0.217      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 799         |
# |    policy_loss        | -154        |
# |    reward             | -0.13787948 |
# |    std                | 0.997       |
# |    value_loss         | 18.7        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 74         |
# |    iterations         | 900        |
# |    time_elapsed       | 60         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 8.24e-05   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | 19.4       |
# |    reward             | 0.41534817 |
# |    std                | 0.999      |
# |    value_loss         | 3.04       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 73        |
# |    iterations         | 1000      |
# |    time_elapsed       | 67        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | -0.0532   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -90.5     |
# |    reward             | 0.8018495 |
# |    std                | 0.997     |
# |    value_loss         | 6.13      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 74       |
# |    iterations         | 1100     |
# |    time_elapsed       | 73       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -41.1    |
# |    explained_variance | 0.00165  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -876     |
# |    reward             | 2.930028 |
# |    std                | 0.997    |
# |    value_loss         | 534      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 75        |
# |    iterations         | 1200      |
# |    time_elapsed       | 79        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | -0.00137  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | 79.9      |
# |    reward             | -9.193484 |
# |    std                | 0.999     |
# |    value_loss         | 12.9      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 75         |
# |    iterations         | 1300       |
# |    time_elapsed       | 86         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | -0.174     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | 50.6       |
# |    reward             | -1.1134107 |
# |    std                | 0.997      |
# |    value_loss         | 2.31       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 75        |
# |    iterations         | 1400      |
# |    time_elapsed       | 92        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | 0.17      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | -18       |
# |    reward             | 3.1162822 |
# |    std                | 0.997     |
# |    value_loss         | 3.22      |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 75           |
# |    iterations         | 1500         |
# |    time_elapsed       | 99           |
# |    total_timesteps    | 7500         |
# | train/                |              |
# |    entropy_loss       | -41          |
# |    explained_variance | 1.19e-07     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1499         |
# |    policy_loss        | 114          |
# |    reward             | -0.068236984 |
# |    std                | 0.996        |
# |    value_loss         | 8.49         |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 75          |
# |    iterations         | 1600        |
# |    time_elapsed       | 105         |
# |    total_timesteps    | 8000        |
# | train/                |             |
# |    entropy_loss       | -41         |
# |    explained_variance | 0.0119      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1599        |
# |    policy_loss        | -197        |
# |    reward             | -0.14361623 |
# |    std                | 0.995       |
# |    value_loss         | 53.9        |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 76       |
# |    iterations         | 1700     |
# |    time_elapsed       | 111      |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -41      |
# |    explained_variance | -0.0226  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -11.9    |
# |    reward             | 1.454355 |
# |    std                | 0.997    |
# |    value_loss         | 6.12     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 76        |
# |    iterations         | 1800      |
# |    time_elapsed       | 118       |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | 0.027     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | 463       |
# |    reward             | 4.7070055 |
# |    std                | 0.997     |
# |    value_loss         | 165       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 76         |
# |    iterations         | 1900       |
# |    time_elapsed       | 123        |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1899       |
# |    policy_loss        | 68.2       |
# |    reward             | 0.59908414 |
# |    std                | 0.997      |
# |    value_loss         | 3.62       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 76          |
# |    iterations         | 2000        |
# |    time_elapsed       | 131         |
# |    total_timesteps    | 10000       |
# | train/                |             |
# |    entropy_loss       | -41.1       |
# |    explained_variance | 0           |
# ...
# |    reward             | 2.964243 |
# |    std                | 1        |
# |    value_loss         | 36.1     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 77       |
# |    iterations         | 400      |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -41.1    |
# |    explained_variance | 0.0345   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -28.6    |
# |    reward             | 0.793971 |
# |    std                | 1        |
# |    value_loss         | 8.9      |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 78         |
# |    iterations         | 500        |
# |    time_elapsed       | 31         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0.0104     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | 329        |
# |    reward             | -1.6800326 |
# |    std                | 0.999      |
# |    value_loss         | 69.2       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 80        |
# |    iterations         | 600       |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | 272       |
# |    reward             | 4.240421  |
# |    std                | 1         |
# |    value_loss         | 59.3      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 77         |
# |    iterations         | 700        |
# |    time_elapsed       | 45         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -119       |
# |    reward             | -0.8151684 |
# |    std                | 1          |
# |    value_loss         | 14.7       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 79         |
# |    iterations         | 800        |
# |    time_elapsed       | 50         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -0.166     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | 52.8       |
# |    reward             | 0.49656135 |
# |    std                | 1          |
# |    value_loss         | 3.22       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 77        |
# |    iterations         | 900       |
# |    time_elapsed       | 57        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | -0.087    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | -100      |
# |    reward             | 1.2221298 |
# |    std                | 1.01      |
# |    value_loss         | 12.8      |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 78           |
# |    iterations         | 1000         |
# |    time_elapsed       | 63           |
# |    total_timesteps    | 5000         |
# | train/                |              |
# |    entropy_loss       | -41.4        |
# |    explained_variance | 4.17e-07     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 999          |
# |    policy_loss        | -9.82        |
# |    reward             | -0.030868627 |
# |    std                | 1.01         |
# |    value_loss         | 0.402        |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 78          |
# |    iterations         | 1100        |
# |    time_elapsed       | 69          |
# |    total_timesteps    | 5500        |
# | train/                |             |
# |    entropy_loss       | -41.4       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1099        |
# |    policy_loss        | 237         |
# |    reward             | -0.12794086 |
# |    std                | 1.01        |
# |    value_loss         | 36.1        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 78        |
# |    iterations         | 1200      |
# |    time_elapsed       | 76        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | 77.4      |
# |    reward             | 3.1932619 |
# |    std                | 1.01      |
# |    value_loss         | 9.44      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 78         |
# |    iterations         | 1300       |
# |    time_elapsed       | 82         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | -0.046     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | 5.51       |
# |    reward             | -1.3655871 |
# |    std                | 1.01       |
# |    value_loss         | 0.139      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 77        |
# |    iterations         | 1400      |
# |    time_elapsed       | 89        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 101       |
# |    reward             | 0.8221583 |
# |    std                | 1.01      |
# |    value_loss         | 9.24      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 78         |
# |    iterations         | 1500       |
# |    time_elapsed       | 95         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1499       |
# |    policy_loss        | -7.55      |
# |    reward             | -1.0237951 |
# |    std                | 1.01       |
# |    value_loss         | 1.48       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 78         |
# |    iterations         | 1600       |
# |    time_elapsed       | 101        |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | 78.4       |
# |    reward             | -1.9269421 |
# |    std                | 1.01       |
# |    value_loss         | 5.61       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 78       |
# |    iterations         | 1700     |
# |    time_elapsed       | 108      |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -41.4    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 129      |
# |    reward             | 0.838456 |
# |    std                | 1.01     |
# |    value_loss         | 27       |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 78         |
# |    iterations         | 1800       |
# |    time_elapsed       | 114        |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | 155        |
# |    reward             | 0.96500844 |
# |    std                | 1.01       |
# |    value_loss         | 25.6       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 78         |
# |    iterations         | 1900       |
# |    time_elapsed       | 121        |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -3.05      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1899       |
# |    policy_loss        | 60.6       |
# |    reward             | -0.5226669 |
# |    std                | 1          |
# |    value_loss         | 3.08       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 78         |
# |    iterations         | 2000       |
# |    time_elapsed       | 127        |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | -198       |
# |    reward             | -3.2009525 |
# |    std                | 1.01       |
# |    value_loss         | 27.6       |
# --------------------------------------
# ======A2C Validation from:  2021-10-04 to  2022-01-03
# A2C Sharpe Ratio:  0.13119145570815194
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to tensorboard_log/ppo/ppo_315_1
# ----------------------------------
# | time/              |           |
# |    fps             | 72        |
# |    iterations      | 1         |
# |    time_elapsed    | 28        |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 1.2647645 |
# ----------------------------------
# day: 3148, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 4191388.91
# total_reward: 3191388.91
# total_cost: 427559.37
# total_trades: 88362
# Sharpe: 0.770
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 2           |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013428236 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.0172     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.48        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0255     |
# |    reward               | 0.5293698   |
# |    std                  | 1           |
# |    value_loss           | 14.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 3           |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014446058 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.00346     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 29.1        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.017      |
# |    reward               | 9.072979    |
# |    std                  | 1           |
# |    value_loss           | 76.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 79           |
# |    iterations           | 4            |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0119833145 |
# |    clip_fraction        | 0.119        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -41.3        |
# |    explained_variance   | -0.00764     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 61.1         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.013       |
# |    reward               | -0.9452      |
# |    std                  | 1            |
# |    value_loss           | 99.8         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 80            |
# |    iterations           | 5             |
# |    time_elapsed         | 127           |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.018924028   |
# |    clip_fraction        | 0.231         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -41.3         |
# |    explained_variance   | 0.0127        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.28          |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.0288       |
# |    reward               | -0.0032127453 |
# |    std                  | 1             |
# |    value_loss           | 12.5          |
# -------------------------------------------
# ======PPO Validation from:  2021-10-04 to  2022-01-03
# PPO Sharpe Ratio:  0.013555343234975738
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cuda device
# Logging to tensorboard_log/ddpg/ddpg_315_1
# day: 3148, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 5993657.15
# total_reward: 4993657.15
# total_cost: 999.00
# total_trades: 59762
# Sharpe: 0.880
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 58        |
# |    time_elapsed    | 216       |
# |    total_timesteps | 12596     |
# | train/             |           |
# |    actor_loss      | 65.1      |
# |    critic_loss     | 2.38e+03  |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 9447      |
# |    reward          | 6.2750473 |
# ----------------------------------
# ======DDPG Validation from:  2021-10-04 to  2022-01-03
# ======Best Model Retraining from:  2009-04-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# Ensemble Strategy took:  32.632273562749226  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126  2021-01-04  2021-04-06        A2C   0.450445    0.30101    0.337519
# 1  189  2021-04-06  2021-07-06       DDPG   0.129404   0.108683    0.265709
# 2  252  2021-07-06  2021-10-04        A2C   0.038418   0.031363    0.027638
# 3  315  2021-10-04  2022-01-03       DDPG   0.131191   0.013555    0.333216

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  0.15112047173135063

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   1.000000e+06  2021-04-06           NaN  2021-04-06
# 1   9.999224e+05  2021-04-07     -0.000078  2021-04-07
# 2   9.994857e+05  2021-04-08     -0.000437  2021-04-08
# 3   1.004493e+06  2021-04-09      0.005010  2021-04-09
# 4   1.002930e+06  2021-04-12     -0.001555  2021-04-12

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return          0.011472
# Cumulative returns     0.011472
# Annual volatility      0.155058
# Sharpe ratio           0.151120
# Calmar ratio           0.087405
# Stability              0.006144
# Max drawdown          -0.131250
# Omega ratio            1.025777
# Sortino ratio          0.213504
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.001231
# Daily value at risk   -0.019443
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return          0.037486
# Cumulative returns     0.037335
# Annual volatility      0.134331
# Sharpe ratio           0.342028
# Calmar ratio           0.331049
# Stability              0.066383
# Max drawdown          -0.113235
# Omega ratio            1.058031
# Sortino ratio          0.480831
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.970301
# Daily value at risk   -0.016742
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
              baseline_ticker = '^DJI', 
              baseline_start = df_account_value.loc[0,'date'],
              baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-04-06</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-04-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>1.147%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>1.147%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>15.506%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.15</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.09</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-13.125%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.03</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.21</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.00</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.944%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.02</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>1.01</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>13.13</td>
#       <td>2021-11-08</td>
#       <td>2021-12-01</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>6.33</td>
#       <td>2021-05-10</td>
#       <td>2021-06-18</td>
#       <td>2021-08-12</td>
#       <td>69</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.45</td>
#       <td>2021-09-03</td>
#       <td>2021-09-21</td>
#       <td>2021-11-01</td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.63</td>
#       <td>2021-08-16</td>
#       <td>2021-08-18</td>
#       <td>2021-08-23</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1.52</td>
#       <td>2021-04-16</td>
#       <td>2021-04-28</td>
#       <td>2021-05-04</td>
#       <td>13</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.01%</td>
#       <td>-3.69%</td>
#       <td>3.46%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# !pip install alpaca-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting alpaca-py
#   Downloading alpaca_py-0.7.1-py3-none-any.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.4/95.4 KB 3.0 MB/s eta 0:00:00
# Collecting requests<3.0.0,>=2.27.1
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<2.0.0,>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from alpaca-py) (1.10.5)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.3 in /usr/local/lib/python3.8/dist-packages (from alpaca-py) (1.0.4)
# Collecting websockets<11.0,>=10.2
#   Downloading websockets-10.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 KB 5.9 MB/s eta 0:00:00
# Collecting sseclient-py<2.0.0,>=1.7.2
#   Downloading sseclient_py-1.7.2-py2.py3-none-any.whl (8.4 kB)
# Requirement already satisfied: pandas<2.0.0,>=1.3.5 in /usr/local/lib/python3.8/dist-packages (from alpaca-py) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas<2.0.0,>=1.3.5->alpaca-py) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas<2.0.0,>=1.3.5->alpaca-py) (2022.7.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from pandas<2.0.0,>=1.3.5->alpaca-py) (1.22.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic<2.0.0,>=1.9.0->alpaca-py) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.27.1->alpaca-py) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.27.1->alpaca-py) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.27.1->alpaca-py) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.27.1->alpaca-py) (3.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas<2.0.0,>=1.3.5->alpaca-py) (1.15.0)
# Installing collected packages: sseclient-py, websockets, requests, alpaca-py
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
# Successfully installed alpaca-py-0.7.1 requests-2.28.2 sseclient-py-1.7.2 websockets-10.4

# %%
# !pip install alpaca
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting alpaca
#   Downloading alpaca-1.0.0.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: alpaca
#   Building wheel for alpaca (setup.py) ... done
#   Created wheel for alpaca: filename=alpaca-1.0.0-py3-none-any.whl size=14089 sha256=553090aef3e70bc4a11dd7f6097fa36413d95a42a1bd3fd55cef61eb4a8b63ec
#   Stored in directory: /root/.cache/pip/wheels/37/c0/67/09e87b64a3d712bead9cfccf3ac045a2926ab94714f4f9ea66
# Successfully built alpaca
# Installing collected packages: alpaca
# Successfully installed alpaca-1.0.0

# %%
from alpaca_trade_api.rest import REST, TimeFrame
import pandas as pd

# %%
pip install alpaca-trade-api
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: alpaca-trade-api in /usr/local/lib/python3.8/dist-packages (3.0.0)
# Requirement already satisfied: pandas>=0.18.1 in /usr/local/lib/python3.8/dist-packages (from alpaca-trade-api) (1.3.5)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.8/dist-packages (from alpaca-trade-api) (1.22.4)
# Requirement already satisfied: requests<3,>2 in /usr/local/lib/python3.8/dist-packages (from alpaca-trade-api) (2.28.2)
# Requirement already satisfied: websockets<11,>=9.0 in /usr/local/lib/python3.8/dist-packages (from alpaca-trade-api) (10.4)
# Requirement already satisfied: PyYAML==6.0 in /usr/local/lib/python3.8/dist-packages (from alpaca-trade-api) (6.0)
# Requirement already satisfied: deprecation==2.1.0 in /usr/local/lib/python3.8/dist-packages (from alpaca-trade-api) (2.1.0)
# Requirement already satisfied: msgpack==1.0.3 in /usr/local/lib/python3.8/dist-packages (from alpaca-trade-api) (1.0.3)
# Requirement already satisfied: aiohttp==3.8.1 in /usr/local/lib/python3.8/dist-packages (from alpaca-trade-api) (3.8.1)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /usr/local/lib/python3.8/dist-packages (from alpaca-trade-api) (1.5.1)
# Requirement already satisfied: urllib3<2,>1.24 in /usr/local/lib/python3.8/dist-packages (from alpaca-trade-api) (1.26.14)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp==3.8.1->alpaca-trade-api) (22.2.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp==3.8.1->alpaca-trade-api) (2.1.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp==3.8.1->alpaca-trade-api) (1.8.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp==3.8.1->alpaca-trade-api) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp==3.8.1->alpaca-trade-api) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp==3.8.1->alpaca-trade-api) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp==3.8.1->alpaca-trade-api) (6.0.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from deprecation==2.1.0->alpaca-trade-api) (23.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.18.1->alpaca-trade-api) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.18.1->alpaca-trade-api) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>2->alpaca-trade-api) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>2->alpaca-trade-api) (2022.12.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas>=0.18.1->alpaca-trade-api) (1.15.0)

# %%
from alpaca.data.historical import StockHistoricalDataClient

# %%
from alpaca.data.historical import CryptoHistoricalDataClient

# %%
from alpaca.data.requests import CryptoBarsRequest
from alpaca.data.timeframe import TimeFrame
import datetime as datetime
from alpaca.data.live import StockDataStream
from alpaca.trading.client import TradingClient
from alpaca.trading.requests import MarketOrderRequest
from alpaca.trading.enums import OrderSide, TimeInForce
from alpaca.trading.requests import LimitOrderRequest
# #I make a cryptocurrency trading bot and hand it a $1000 dollars and leave it to trade that unsupervised for a week.

# # paper=True enables paper trading
trading_client = TradingClient('PKSQ5TPJ7JU7ACK9J6L4', 'cA8eTdjNnBj5vKvgjXBF9lSJFiAtt51BNa7dG8JP', paper=True)

# %%
from alpaca_trade_api.rest import REST, TimeFrame
import pandas as pd

# %%
import alpaca_trade_api as tradeapi
import pandas as pd
import datetime
from alpaca.data.historical import CryptoHistoricalDataClient
from alpaca.data.requests import CryptoBarsRequest
from alpaca.data.timeframe import TimeFrame

# Replace the placeholders below with your own API credentials
api_key = 'PKSQ5TPJ7JU7ACK9J6L4'
api_secret = 'cA8eTdjNnBj5vKvgjXBF9lSJFiAtt51BNa7dG8JP'
base_url = 'https://paper-api.alpaca.markets'

# no keys required for crypto data
client = CryptoHistoricalDataClient()

GET/v2/stocks/{BTC/USD}/trades
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-93b0e436ab35> in <module>
#      14 client = CryptoHistoricalDataClient()
#      15
# ---> 16 GET/v2/stocks/{BTC/USD}/trades
#
# NameError: name 'GET' is not defined

# %%
import alpaca_trade_api as tradeapi
import pandas as pd
import datetime
from alpaca.data.historical import CryptoHistoricalDataClient
from alpaca.data.requests import CryptoBarsRequest
from alpaca.data.timeframe import TimeFrame

# Replace the placeholders below with your own API credentials
api_key = 'PKSQ5TPJ7JU7ACK9J6L4'
api_secret = 'cA8eTdjNnBj5vKvgjXBF9lSJFiAtt51BNa7dG8JP'
base_url = 'https://paper-api.alpaca.markets'

# no keys required for crypto data
client = CryptoHistoricalDataClient()

request_params = CryptoBarsRequest(
                        symbol_or_symbols=['BTC/USD', 'ETH/USD'],
                        timeframe=TimeFrame.Day,
                        start='2022, 1, 1'
                 )

bars = client.get_crypto_bars(request_params)

# The bars variable now contains a Pandas DataFrame with the historical bars data
print(bars)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-51-30d0cde75a78> in <module>
#      14 client = CryptoHistoricalDataClient()
#      15
# ---> 16 request_params = CryptoBarsRequest(
#      17                         symbol_or_symbols=['BTC/USD', 'ETH/USD'],
#      18                         timeframe=TimeFrame.Day,
#
# /usr/local/lib/python3.8/dist-packages/alpaca/data/requests.py in __init__(self, **data)
#      43             data["end"] = data["end"].astimezone(pytz.utc).replace(tzinfo=None)
#      44
# ---> 45         super().__init__(**data)
#      46
#      47
#
# /usr/local/lib/python3.8/dist-packages/pydantic/main.cpython-38-x86_64-linux-gnu.so in pydantic.main.BaseModel.__init__()
#
# ValidationError: 1 validation error for CryptoBarsRequest
# start
#   invalid datetime format (type=value_error.datetime)

# %%
# Create a market order to buy 1 Bitcoin
order_buy = api.submit_order('NVDA', qty=0.001, side='buy', time_in_force=TimeInForce.DAY)

# %%
market_order_data = MarketOrderRequest(
                   symbol="BTCUSD",
                   qty=0.001,
                   side=OrderSide.BUY,
                   time_in_force=TimeInForce.DAY)

market_order = trading_client.submit_order(
               order_data=market_order_data
              )
print(market_order)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/alpaca/common/rest.py in _one_request(self, method, url, opts, retry)
#     186         try:
# --> 187             response.raise_for_status()
#     188         except HTTPError as http_error:
#
# /usr/local/lib/python3.8/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 422 Client Error: Unprocessable Entity for url: https://paper-api.alpaca.markets/v2/orders
#
# During handling of the above exception, another exception occurred:
#
# APIError                                  Traceback (most recent call last)
# <ipython-input-23-62425266c023> in <module>
#       5                    time_in_force=TimeInForce.DAY)
#       6
# ----> 7 market_order = trading_client.submit_order(
#       8                order_data=market_order_data
#       9               )
#
# /usr/local/lib/python3.8/dist-packages/alpaca/trading/client.py in submit_order(self, order_data)
#      89         """
#      90         data = order_data.to_request_fields()
# ---> 91         response = self.post("/orders", data)
#      92
#      93         if self._use_raw_data:
#
# /usr/local/lib/python3.8/dist-packages/alpaca/common/rest.py in post(self, path, data)
#     223             dict: The response
#     224         """
# --> 225         return self._request("POST", path, data)
#     226
#     227     def put(self, path: str, data: Union[dict, str] = None) -> dict:
#
# /usr/local/lib/python3.8/dist-packages/alpaca/common/rest.py in _request(self, method, path, data, base_url, api_version)
#     124         while retry >= 0:
#     125             try:
# --> 126                 return self._one_request(method, url, opts, retry)
#     127             except RetryException:
#     128                 time.sleep(self._retry_wait)
#
# /usr/local/lib/python3.8/dist-packages/alpaca/common/rest.py in _one_request(self, method, url, opts, retry)
#     194             error = response.text
#     195
# --> 196             raise APIError(error, http_error)
#     197
#     198         if response.text != "":
#
# APIError: {"code":42210000,"message":"invalid crypto time_in_force"}

# %%
##Market Order 
# preparing orders
market_order_data = MarketOrderRequest(
                    symbol="NVDA",
                    qty=1,
                    side=OrderSide.SELL,
                    time_in_force=TimeInForce.DAY
                    )

# Market order
market_order = trading_client.submit_order(
               order_data=market_order_data
              )

# if(DRLEnsembleAGent.Sharpe > .4)

# # Market order
# market_order = trading_client.submit_order(fndsdsdsfdsdsf
#                 order_data=market_order_data
#                )

# else

# print(no trades for today)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/alpaca/common/rest.py in _one_request(self, method, url, opts, retry)
#     186         try:
# --> 187             response.raise_for_status()
#     188         except HTTPError as http_error:
#
# /usr/local/lib/python3.8/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 401 Client Error: Unauthorized for url: https://api.alpaca.markets/v2/orders
#
# During handling of the above exception, another exception occurred:
#
# APIError                                  Traceback (most recent call last)
# <ipython-input-8-e73f3367b087> in <module>
#       9
#      10 # Market order
# ---> 11 market_order = trading_client.submit_order(
#      12                order_data=market_order_data
#      13               )
#
# /usr/local/lib/python3.8/dist-packages/alpaca/trading/client.py in submit_order(self, order_data)
#      89         """
#      90         data = order_data.to_request_fields()
# ---> 91         response = self.post("/orders", data)
#      92
#      93         if self._use_raw_data:
#
# /usr/local/lib/python3.8/dist-packages/alpaca/common/rest.py in post(self, path, data)
#     223             dict: The response
#     224         """
# --> 225         return self._request("POST", path, data)
#     226
#     227     def put(self, path: str, data: Union[dict, str] = None) -> dict:
#
# /usr/local/lib/python3.8/dist-packages/alpaca/common/rest.py in _request(self, method, path, data, base_url, api_version)
#     124         while retry >= 0:
#     125             try:
# --> 126                 return self._one_request(method, url, opts, retry)
#     127             except RetryException:
#     128                 time.sleep(self._retry_wait)
#
# /usr/local/lib/python3.8/dist-packages/alpaca/common/rest.py in _one_request(self, method, url, opts, retry)
#     194             error = response.text
#     195
# --> 196             raise APIError(error, http_error)
#     197
#     198         if response.text != "":
#
# APIError: {"code":40110000,"message":"request is not authorized"}
